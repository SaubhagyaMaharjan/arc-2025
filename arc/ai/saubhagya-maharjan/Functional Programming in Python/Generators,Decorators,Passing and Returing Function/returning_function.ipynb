# %%
def out():
    print('I am outside.')
    
    # Defining function within function
    def inner_func():
        print("I am inside.")
    
    return inner_func  # Returning reference to inner_func

my_func = out()   # This will print 'I am outside.'
my_func()         # This will now call inner_func and print 'I am inside.'
# Out:
# I am outside.
# I am inside.
