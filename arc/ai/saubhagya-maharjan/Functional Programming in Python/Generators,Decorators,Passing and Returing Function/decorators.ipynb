# %%
''' decorators is a design pattern in Python that allows a user to add new functionality to an existing functions
object without modifying its structure.
## Real-Life Use Cases of Decorators
1. Logging
2.Authentication (before allowing access)
3. Measuring execution time
4. Caching/memoization
5. Validation checks
'''

# %%
def my_decorator(func):
    def wrapper():
        print("Before function call")
        result = func()
        print("After function call")
        return result
    return wrapper

@my_decorator
def greet():
    return "hello"

print(greet())
# Out:
# Before function call
# After function call
# hello
