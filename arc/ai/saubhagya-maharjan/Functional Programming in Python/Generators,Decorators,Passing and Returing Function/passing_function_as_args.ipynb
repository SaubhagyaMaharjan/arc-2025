# %%
def func1():
    print("Hello from func1.")
def func2(func):
    print("Hello from func2.")
    func()

# %%
# Calling func2 with func1 as an argument
func2(func1)  # We pass only reference to func1 object
# Out:
# Hello from func2.
# Hello from func1.
